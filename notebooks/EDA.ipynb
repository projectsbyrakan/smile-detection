# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('image_with_label.csv')

# %%
df
# Out:
#      image_name smiling
# 0         1.jpg      no
# 1         2.jpg     yes
# 2         3.jpg     yes
# 3         4.jpg     yes
# 4         5.jpg     yes
# ...         ...     ...
# 9995   9996.jpg     yes
# 9996   9997.jpg      no
# 9997   9998.jpg     yes
# 9998   9999.jpg     yes
# 9999  10000.jpg     yes
#
# [10000 rows x 2 columns]

# %%
df.dtypes
# Out:
# image_name    str
# smiling       str
# dtype: object

# %%
df.isna().sum()
# Out:
# image_name    0
# smiling       0
# dtype: int64

# %%
df['smiling'].value_counts()
# Out:
# smiling
# yes    7000
# no     3000
# Name: count, dtype: int64

# %%
from PIL import Image
import os

# %%
for i in os.listdir('images'):
    try:
        image = Image.open(f'images/{i}')
        image.verify()
    except:
        print(f'{i} is not a valid image')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_paths = os.listdir('images')[4:8]
labels = df['smiling'][4:8]
_ , axes = plt.subplots(2, 2, figsize=(10, 10))

for fig, img in zip(axes.flatten(), image_paths):
    image = mpimg.imread(os.path.join('images', img))
    fig.imshow(image)
    fig.set_title(f'smiling: {labels[i]}')
    fig.axis('off')

plt.tight_layout()
plt.show()
